# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load('../../Data/Spiral/rotated.npy')

random_mat = np.random.rand(10, 10)
sparsity_matrix = np.random.uniform(0, 1, (10, 10))

sparsity_th = 0
sparsity_matrix = sparsity_matrix > sparsity_th

random_mat = random_mat * sparsity_matrix

# %%
data.shape
# Out:
# (6, 10, 1000)

# %%
random_mat
# Out:
# array([[0.16656058, 0.07533489, 0.90173075, 0.60923279, 0.8445811 ,
#         0.59119   , 0.3372005 , 0.01155814, 0.58257823, 0.81152576],
#        [0.88847959, 0.47214798, 0.37591326, 0.05861032, 0.91326283,
#         0.34478029, 0.16259967, 0.74913048, 0.46323834, 0.86378829],
#        [0.19395282, 0.29758929, 0.70535883, 0.32953463, 0.79911917,
#         0.46346295, 0.28968708, 0.01871876, 0.1860345 , 0.34770521],
#        [0.65176001, 0.7180083 , 0.77939697, 0.11715011, 0.32971446,
#         0.5531733 , 0.4142264 , 0.28601828, 0.24789117, 0.06763315],
#        [0.92230712, 0.22079142, 0.54021064, 0.40792731, 0.4258456 ,
#         0.38368492, 0.21568254, 0.3712322 , 0.21128269, 0.15355075],
#        [0.48956028, 0.60894764, 0.91250416, 0.11940548, 0.6851301 ,
#         0.98493247, 0.67946868, 0.19287172, 0.86979238, 0.29563028],
#        [0.09164167, 0.59142488, 0.83582365, 0.24516681, 0.68450565,
#         0.9071003 , 0.01792033, 0.61573012, 0.1220768 , 0.55676204],
#        [0.39300164, 0.77677925, 0.45234487, 0.1028575 , 0.00834635,
#         0.82634061, 0.01151529, 0.93615431, 0.33064638, 0.18800903],
#        [0.43382405, 0.72143217, 0.5145383 , 0.50345514, 0.06196324,
#         0.97365735, 0.34911372, 0.93343848, 0.55485538, 0.13576082],
#        [0.45573669, 0.12861339, 0.3803122 , 0.14725447, 0.81164203,
#         0.4107094 , 0.17629573, 0.0558261 , 0.37726781, 0.76862126]])

# %%
for i in range(10):
    plt.plot(np.arange(1000), data[0, i, :], 'o')

# %%
shape_0 = data.shape[0]
shape_1 = data.shape[1]
shape_2 = data.shape[2]

data_transform = np.zeros((shape_0, shape_1, shape_2))
data_transform.shape
# Out:
# (6, 10, 1000)

# %%
for i in range(data.shape[0]):
    data_transform[i, :, :] = random_mat @ data[i, :, :]

data_transform.shape
# Out:
# (6, 10, 1000)

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
for i in range(6):
    ax[0].plot(np.arange(1000), data_transform[i, 0, :])
    
for i in range(6):
    ax[1].plot(np.arange(1000), data[i, 0, :])

# %%
np.save('../../Data/Measurement/explode-measured.npy', data_transform)
