# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load('../../Data/Spiral/rotated.npy')

random_mat = np.random.rand(10, 10)
sparsity_matrix = np.random.uniform(0, 1, (10, 10))

sparsity_th = 0
sparsity_matrix = sparsity_matrix > sparsity_th

random_mat = random_mat * sparsity_matrix

# %%
data.shape
# Out:
# (6, 10, 1000)

# %%
random_mat
# Out:
# array([[0.71004724, 0.17778719, 0.59783395, 0.17446654, 0.97335778,
#         0.622721  , 0.6129462 , 0.6254376 , 0.58430871, 0.18593556],
#        [0.73900409, 0.34616372, 0.35218036, 0.26412585, 0.08436107,
#         0.32939754, 0.00816567, 0.09881753, 0.37423757, 0.15068325],
#        [0.58120263, 0.38501424, 0.28245017, 0.65326619, 0.65703882,
#         0.53981222, 0.24443182, 0.07537822, 0.77767099, 0.40056729],
#        [0.93096004, 0.30210209, 0.52968583, 0.20123921, 0.66428857,
#         0.32108946, 0.51385298, 0.44621586, 0.73957937, 0.20489868],
#        [0.48893737, 0.50994817, 0.2688397 , 0.67120121, 0.26096557,
#         0.26135596, 0.38659304, 0.17432943, 0.82635983, 0.94535296],
#        [0.69303766, 0.81771113, 0.84685786, 0.80558474, 0.60303347,
#         0.445049  , 0.04852766, 0.57811146, 0.37402571, 0.78243843],
#        [0.25683661, 0.660821  , 0.14375801, 0.67675419, 0.57039018,
#         0.95985984, 0.26651982, 0.9294829 , 0.61133268, 0.45472171],
#        [0.78632986, 0.65661495, 0.38638888, 0.85866647, 0.43655224,
#         0.31867592, 0.5817675 , 0.59464963, 0.42177629, 0.33379169],
#        [0.51227411, 0.67149802, 0.60305625, 0.31667025, 0.10530426,
#         0.90148331, 0.71114055, 0.41278949, 0.1263221 , 0.82076675],
#        [0.87452201, 0.47863615, 0.56932307, 0.08229763, 0.62407567,
#         0.44375366, 0.42231288, 0.79934299, 0.4366668 , 0.63348818]])

# %%
for i in range(10):
    plt.plot(np.arange(1000), data[0, i, :], 'o')

# %%
shape_0 = data.shape[0]
shape_1 = data.shape[1]
shape_2 = data.shape[2]

data_transform = np.zeros((shape_0, shape_1, shape_2))
data_transform.shape
# Out:
# (6, 10, 1000)

# %%
for i in range(data.shape[0]):
    data_transform[i, :, :] = random_mat @ data[i, :, :]

data_transform.shape
# Out:
# (6, 10, 1000)

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
for i in range(6):
    ax[0].plot(np.arange(1000), data_transform[i, 0, :])
    
for i in range(6):
    ax[1].plot(np.arange(1000), data[i, 0, :])

# %%
np.save('../../Data/Measurement/explode-measured.npy', data_transform)
